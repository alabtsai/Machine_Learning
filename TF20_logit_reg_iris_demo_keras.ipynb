# %%
import numpy as np
import tensorflow as tf
np.random.seed(2042)

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %%
from tensorflow import keras

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(2,)),
    keras.layers.Dense(3,activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 2)                 0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 9
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers

# %%
model.layers[0]

# %%
lay0=model.layers[0]
lay0.name
# Out:
# 'flatten'

# %%
lay1=model.layers[1]
lay1.name
# Out:
# 'dense'

# %%
lay0.get_weights()
# Out:
# []

# %%
lay1.get_weights()
# Out:
# [array([[ 0.8043325 , -0.6097455 , -0.7269653 ],
#         [-0.84936476,  0.97786784, -0.80104303]], dtype=float32),
#  array([0., 0., 0.], dtype=float32)]

# %%
len(lay1.get_weights())
# Out:
# 2

# %% [markdown]
# ### To compare whether we get the same weights, we use the same initial weights as before

# %%
matrix=np.array([[ 0.43433246, -0.66647124, -0.71757054],
       [ 1.0188498 ,  0.41245225, -0.7501844 ]])

# %%
bias=np.array([ 0.11330361, -0.23452355, -0.20774285])

# %%
lay1.set_weights([matrix,bias])

# %%
lay1.get_weights()
# Out:
# [array([[ 0.43433246, -0.66647124, -0.71757054],
#         [ 1.0188498 ,  0.41245225, -0.7501844 ]], dtype=float32),
#  array([ 0.11330361, -0.23452355, -0.20774285], dtype=float32)]

# %%
X_train_wo_bias.shape
# Out:
# (90, 2)

# %% [markdown]
# ### one-hot vector -->

# %%
model.compile(loss="categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])

# %%
history = model.fit(X_train_wo_bias, Y_train_one_hot, batch_size=train_size, epochs=5000)
# Out:
# Train on 90 samples
# Epoch 1/5000
# 90/90 [==============================] - 1s 14ms/sample - loss: 5.4479 - accuracy: 0.3444
# Epoch 2/5000
# 90/90 [==============================] - 0s 24us/sample - loss: 5.2715 - accuracy: 0.3444
# Epoch 3/5000
# 90/90 [==============================] - 0s 30us/sample - loss: 5.0959 - accuracy: 0.3444
# Epoch 4/5000
# 90/90 [==============================] - 0s 31us/sample - loss: 4.9212 - accuracy: 0.3444
# Epoch 5/5000
# 90/90 [==============================] - 0s 33us/sample - loss: 4.7475 - accuracy: 0.3444
# Epoch 6/5000
# 90/90 [==============================] - 0s 34us/sample - loss: 4.5749 - accuracy: 0.3444
# Epoch 7/5000
# 90/90 [==============================] - 0s 24us/sample - loss: 4.4036 - accuracy: 0.3444
# Epoch 8/5000
# 90/90 [==============================] - 0s 45us/sample - loss: 4.2336 - accuracy: 0.3444
# Epoch 9/5000
# 90/90 [==============================] - 0s 36us/sample - loss: 4.0651 - accuracy: 0.3444
# ...

# %%
lay1.get_weights()
# Out:
# [array([[-1.1717904 ,  0.11701398,  0.10506771],
#         [-0.7021253 , -0.09518026,  1.4784203 ]], dtype=float32),
#  array([ 3.320635  , -0.65012634, -2.999467  ], dtype=float32)]

# %%
 [[ 3.32063207 -0.65012726 -2.9994676 ]
 [-1.17179014  0.11701372  0.10506711]
 [-0.70212433 -0.0951797   1.47842168]]

# %%
matrix=np.array([[-2.909397  , -0.16438407,  2.1241298 ],
       [-4.368392  , -0.90395266,  5.951257  ]])

# %%
bias=np.array([ 14.029167,   4.02366 , -18.383087])

# %%
lay1.set_weights([matrix,bias])

# %%
lay1.get_weights()
# Out:
# [array([[-2.909397  , -0.16438407,  2.1241298 ],
#         [-4.368392  , -0.90395266,  5.951257  ]], dtype=float32),
#  array([ 14.029167,   4.02366 , -18.383087], dtype=float32)]

# %%
history = model.fit(X_train_wo_bias, Y_train_one_hot, batch_size=train_size, epochs=5000)
# Out:
# Train on 90 samples
# Epoch 1/5000
# 90/90 [==============================] - 0s 48us/sample - loss: 0.0875 - accuracy: 0.9667
# Epoch 2/5000
# 90/90 [==============================] - 0s 18us/sample - loss: 0.0875 - accuracy: 0.9667
# Epoch 3/5000
# 90/90 [==============================] - 0s 20us/sample - loss: 0.0875 - accuracy: 0.9667
# Epoch 4/5000
# 90/90 [==============================] - 0s 23us/sample - loss: 0.0875 - accuracy: 0.9667
# Epoch 5/5000
# 90/90 [==============================] - 0s 25us/sample - loss: 0.0875 - accuracy: 0.9667
# Epoch 6/5000
# 90/90 [==============================] - 0s 20us/sample - loss: 0.0875 - accuracy: 0.9667
# Epoch 7/5000
# 90/90 [==============================] - 0s 19us/sample - loss: 0.0875 - accuracy: 0.9667
# Epoch 8/5000
# 90/90 [==============================] - 0s 17us/sample - loss: 0.0875 - accuracy: 0.9667
# Epoch 9/5000
# 90/90 [==============================] - 0s 19us/sample - loss: 0.0875 - accuracy: 0.9667
# ...

# %%
lay1.get_weights()
# Out:
# [array([[-2.922704  , -0.17025496,  2.1432033 ],
#         [-4.392234  , -0.90633684,  5.9774833 ]], dtype=float32),
#  array([ 14.106797 ,   4.0665755, -18.507065 ], dtype=float32)]

# %%
lay1.get_weights()
# Out:
# [array([[-2.780218  , -0.36398938,  1.4807651 ],
#         [-4.8805137 , -1.2476584 ,  5.1451654 ]], dtype=float32),
#  array([ 12.659842 ,   3.4237826, -16.08422  ], dtype=float32)]

# %%
history.params
# Out:
# {'batch_size': 90,
#  'epochs': 5000,
#  'steps': 1,
#  'samples': 90,
#  'verbose': 1,
#  'do_validation': False,
#  'metrics': ['loss', 'accuracy']}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
model.predict([[5,2]])
# Out:
# array([[1.3486563e-06, 5.9452079e-02, 9.4054657e-01]], dtype=float32)

# %%
print(history.history['loss'])
# Out:
# [0.08747747540473938, 0.08747736364603043, 0.08747725933790207, 0.08747721463441849, 0.08747708797454834, 0.08747698366641998, 0.08747687190771103, 0.08747678995132446, 0.08747666329145432, 0.08747656643390656, 0.08747649937868118, 0.08747635781764984, 0.08747629821300507, 0.08747618645429611, 0.08747607469558716, 0.0874759629368782, 0.08747585862874985, 0.0874757468700409, 0.08747565001249313, 0.08747557550668716, 0.08747543394565582, 0.08747536689043045, 0.08747527003288269, 0.08747514337301254, 0.08747505396604538, 0.08747495710849762, 0.08747483044862747, 0.08747472614049911, 0.08747463673353195, 0.087474524974823, 0.08747442811727524, 0.08747433125972748, 0.08747422695159912, 0.08747415244579315, 0.087474025785923, 0.08747395128011703, 0.08747382462024689, 0.08747373521327972, 0.08747360855340958, 0.08747349679470062, 0.08747342973947525, 0.08747328817844391, 0.08747322112321854, 0.08747312426567078, 0.08747301995754242, 0.08747291564941406, 0.0874728187918663, 0.087472707033157
# ...

# %%
import pandas as pd
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
#save_fig("keras_learning_curves_plot")
plt.show()

# %%
from sklearn import datasets
iris=datasets.load_iris()
list(iris.keys())
# Out:
# ['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
X = iris["data"][:, (2, 3)]  # petal length, petal width
y = iris["target"]
print(len(X))
print(X.shape)
# Out:
# 150
# (150, 2)

# %%
X=X.astype('float32')
print(X.dtype)
print(X.shape)
# Out:
# float32
# (150, 2)

# %%
X_with_bias = np.c_[np.ones([len(X), 1]), X]

# %%
test_ratio = 0.2
validation_ratio = 0.2
total_size = len(X_with_bias)

test_size = int(total_size * test_ratio)
validation_size = int(total_size * validation_ratio)
train_size = total_size - test_size - validation_size

rnd_indices = np.random.permutation(total_size)

# %%
X_train = X_with_bias[rnd_indices[:train_size]]
y_train = y[rnd_indices[:train_size]]
X_valid = X_with_bias[rnd_indices[train_size:-test_size]]
y_valid = y[rnd_indices[train_size:-test_size]]
X_test = X_with_bias[rnd_indices[-test_size:]]
y_test = y[rnd_indices[-test_size:]]

# %%
X_train_wo_bias = X[rnd_indices[:train_size]]
print(X_train_wo_bias.shape)
# Out:
# (90, 2)

# %%
def to_one_hot(y):
    n_classes = y.max() + 1
    m = len(y)
    Y_one_hot = np.zeros((m, n_classes))
    Y_one_hot[np.arange(m), y] = 1
    return Y_one_hot

# %%
y_train[:10]
# Out:
# array([0, 1, 2, 1, 1, 0, 1, 1, 1, 0])

# %%
to_one_hot(y_train[:7])
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.],
#        [0., 1., 0.],
#        [0., 1., 0.],
#        [1., 0., 0.],
#        [0., 1., 0.]])

# %%
Y_train_one_hot = to_one_hot(y_train)
Y_valid_one_hot = to_one_hot(y_valid)
Y_test_one_hot = to_one_hot(y_test)

# %%
def softmax(logits):
    exps = np.exp(logits)
    exp_sums = np.sum(exps, axis=1, keepdims=True)
    return exps / exp_sums

# %%
Theta = np.array([[ 0.11330361, -0.23452355, -0.20774285],
                  [ 0.43433246, -0.66647124, -0.71757054],
                  [ 1.0188498 ,  0.41245225, -0.7501844 ]])

# %%
eta = 0.01
n_iterations = 5001
m = len(X_train)
epsilon = 1e-7


for iteration in range(n_iterations):
    if iteration % 500 == 0:
        print(Theta)
    logits = X_train.dot(Theta)
    Y_proba = softmax(logits)
    loss = -np.mean(np.sum(Y_train_one_hot * np.log(Y_proba + epsilon), axis=1))
    error = Y_proba - Y_train_one_hot
    if iteration % 500 == 0:
        print(iteration, loss)
    gradients = 1/m * X_train.T.dot(error)
    if iteration % 500 == 0:
        print(iteration, gradients)
        print(' ')
    Theta = Theta - eta * gradients
# Out:
# [[ 0.11330361 -0.23452355 -0.20774285]
#  [ 0.43433246 -0.66647124 -0.71757054]
#  [ 1.0188498   0.41245225 -0.7501844 ]]
# 0 5.446205761132319
# 0 [[ 0.59406399 -0.28615298 -0.30791101]
#  [ 3.17973972 -1.34526175 -1.83447798]
#  [ 1.10140275 -0.43091503 -0.67048771]]
#
# [[ 0.66543332 -0.31522188 -0.67917423]
#  [-0.71766509 -0.28252864  0.05048441]
#  [ 0.34684639  0.45492833 -0.12065707]]
# 500 0.8350062649757334
# 500 [[-0.13595679  0.02841431  0.10754247]
#  [ 0.01794235 -0.01436509 -0.00357726]
#  [ 0.05473265  0.01235083 -0.06708348]]
#
# [[ 1.25032978 -0.43868014 -1.14061243]
#  [-0.80225326 -0.21268549  0.06522943]
#  [ 0.11147053  0.3923484   0.17729872]]
# 1000 0.687880146527562
# 1000 [[-0.10042224  0.02081561  0.07960662]
#  [ 0.01573514 -0.01335253 -0.00238261]
#  [ 0.04034821  0.01283161 -0.05317983]]
#
# [[ 1.69138727 -0.52528704 -1.49506303]
#  [-0.87478246 -0.14991561  0.07498875]
#  [-0.06523298  0.32667215  0.41967848]]
# 1500 0.6012379160992423
# ...
